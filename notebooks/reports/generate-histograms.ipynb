# %%
from hiscores.data import load_hiscores_data
from hiscores.visualization import player_skills_histogram

# %%
ranks, levels, xp = load_hiscores_data()
# Out:
# loading hiscores data... done

# %%
skill = 'attack'
annotations = {
    40: {'text': 'Rune', 'x': 40, 'y_frac': 0.70},
    60: {'text': 'T60', 'x': 60, 'y_frac': 0.90},
    70: {'text': 'T70', 'x': 70, 'y_frac': 0.90},
    75: {'text': 'T75', 'x': 75, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'strength'
annotations = {
    50: {'text': 'Granite\nmaul', 'x': 50, 'y_frac': 0.70},
    70: {'text': 'T70 (Dharok\'s)', 'x': 70, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'defence'
annotations = {
    2: {'text': 'Failed\npures', 'x': 4, 'y_frac': 0.70},
    10: {'text': 'Initiate\npures', 'x': 9, 'y_frac': 0.50},
    13: {'text': '13 def\npures', 'x': 13, 'y_frac': 0.70},
    20: {'text': 'T20\n(Studded/\nMystic)', 'x': 20, 'y_frac': 0.70},
    25: {'text': 'T25\n(Infinity)', 'x': 30, 'y_frac': 0.70},
    40: {'text': 'T40 (Rune)', 'x': 40, 'y_frac': 0.70},
    45: {'text': 'Zerkers', 'x': 42, 'y_frac': 0.90},
    50: {'text': 'Granite\n(bots?)', 'x': 50, 'y_frac': 0.85},
    60: {'text': 'T60 (Dragon)', 'x': 60, 'y_frac': 0.90},
    70: {'text': 'T70', 'x': 70, 'y_frac': 0.90},
    75: {'text': 'T75', 'x': 75, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'ranged'
annotations = {
    13: {'text': 'Death to the Dorgeshuun\nquest reward? (2000 xp)', 'x': 9, 'y_frac': 0.70},
    20: {'text': 'Coif/\nstudded', 'x': 22, 'y_frac': 0.70},
    40: {'text': 'Green d\'hide', 'x': 40, 'y_frac': 0.70},
    50: {'text': 'Nobody stops\nat blue d\'hide!', 'x': 50, 'y_frac': 0.80},
    60: {'text': 'Red d\'hide', 'x': 60, 'y_frac': 0.90},
    70: {'text': 'T70', 'x': 70, 'y_frac': 0.90},
    75: {'text': 'T75', 'x': 75, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'magic'
annotations = {
    40: {'text': 'Mystic/enchanted', 'x': 40, 'y_frac': 0.70},
    55: {'text': 'High-level alchemy', 'x': 55, 'y_frac': 0.80},
    70: {'text': 'T70/\nIce burst', 'x': 70, 'y_frac': 0.85},
    75: {'text': 'T75', 'x': 75, 'y_frac': 0.90},
    94: {'text': 'Ice barrage', 'x': 90, 'y_frac': 0.85},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'prayer'
annotations = {
    11: {'text': 'Priest in Peril\nquest reward\n(1406 xp)', 'x': 7, 'y_frac': 0.65},
    13: {'text': '13 prayer\npure', 'x': 13, 'y_frac': 0.50},
    15: {'text': 'Priest in Peril +\nRestless Ghost\nquest reward (2531 xp)', 'x': 19, 'y_frac': 0.70},
    31: {'text': '31 prayer\npure', 'x': 31, 'y_frac': 0.55},
    43: {'text': 'Protect melee', 'x': 43, 'y_frac': 0.90},
    52: {'text': 'Smite', 'x': 52, 'y_frac': 0.90},
    60: {'text': 'Chivalry', 'x': 60, 'y_frac': 0.90},
    70: {'text': 'Piety', 'x': 69, 'y_frac': 0.90},
    74: {'text': 'Rigour', 'x': 74, 'y_frac': 0.90},
    77: {'text': 'Augury', 'x': 79, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'hitpoints'
annotations = {
    10: {'text': 'skillers', 'x': 10, 'y_frac': 0.65},
    11: {'text': '', 'x': 45, 'y_frac': 0.70},
    57: {'text': 'players in top 2 million overall\nwho are not ranked for HP', 'x': 45, 'y_frac': 0.70},
    58: {'text': 'cutoff level for being\nranked top 2 million in HP', 'x': 58, 'y_frac': 0.85},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'agility'
annotations = {
    21: {'text': 'GE shortcut', 'x': 21, 'y_frac': 0.70},
    35: {'text': 'Horror from\nthe Deep', 'x': 33, 'y_frac': 0.85},
    40: {'text': 'Fremennik\nIsles', 'x': 42, 'y_frac': 0.85},
    50: {'text': 'Legends\'\nQuest', 'x': 50, 'y_frac': 0.85},
    60: {'text': 'DS2', 'x': 60, 'y_frac': 0.90},
    70: {'text': 'SoTE', 'x': 70, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'construction'
annotations = {
    50: {'text': 'Portal chamber', 'x': 50, 'y_frac': 0.90},
    70: {'text': 'SoTE', 'x': 70, 'y_frac': 0.90},
    83: {'text': 'lowest level needed\nfor maxed house', 'x': 83, 'y_frac': 0.85},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'thieving'
annotations = {
    53: {'text': 'Desert Treasure', 'x': 53, 'y_frac': 0.90},
    60: {'text': 'DS2', 'x': 60, 'y_frac': 0.90},
    70: {'text': 'paladins', 'x': 66, 'y_frac': 0.85},
    72: {'text': 'hard Ardougne\ndiary', 'x': 72, 'y_frac': 0.875},
    75: {'text': 'hard\nFremennik/Western\nProvinces diaries', 'x': 81, 'y_frac': 0.80},
    91: {'text': 'elite\nDesert diary', 'x': 91, 'y_frac': 0.75},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'cooking'
annotations = {
    70: {'text': 'RFD/SoTE', 'x': 70, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'firemaking'
annotations = {
    50: {'text': 'Desert Treasure', 'x': 50, 'y_frac': 0.90},
    60: {'text': 'MM2', 'x': 60, 'y_frac': 0.90},
    66: {'text': 'Making Friends\nwith My Arm', 'x': 68, 'y_frac': 0.85},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'slayer'
annotations = {
    9: {'text': '1000 xp reward \n(several quests)', 'x': 7, 'y_frac': 0.70},
    13: {'text': '2000 xp', 'x': 13, 'y_frac': 0.65},
    55: {'text': 'slayer helmet', 'x': 55, 'y_frac': 0.90},
    69: {'text': 'MM2', 'x': 64, 'y_frac': 0.85},
    70: {'text': 'SoTE', 'x': 67, 'y_frac': 0.90},
    72: {'text': 'skeletal\nwyverns', 'x': 72, 'y_frac': 0.85},
    75: {'text': 'gargoyles', 'x': 78, 'y_frac': 0.85},
    77: {'text': 'brutal black\ndragons', 'x': 84, 'y_frac': 0.85},
    85: {'text': 'abyssal demons', 'x': 90, 'y_frac': 0.80},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'smithing'
annotations = {
    20: {'text': 'Elemental Workshop I/\nTourist Trap', 'x': 20, 'y_frac': 0.90},
    40: {'text': 'gold bars', 'x': 40, 'y_frac': 0.90},
    50: {'text': 'Legends\' Quest', 'x': 50, 'y_frac': 0.90},
    60: {'text': 'Fremennik\nExiles/hard\nFremennik diary', 'x': 60, 'y_frac': 0.80},
    70: {'text': 'DS2/SoTE', 'x': 70, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'runecraft'
annotations = {
    9: {'text': 'easy Varrock Diary', 'x': 9, 'y_frac': 0.90},
    55: {'text': 'Fremennik Exiles', 'x': 55, 'y_frac': 0.90},
    77: {'text': 'blood runes', 'x': 77, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'fletching'
annotations = {
    9: {'text': 'Animal Magnetism\nquest reward (1000 xp)', 'x': 12, 'y_frac': 0.70},
    50: {'text': 'medium Kandarin\ndiary', 'x': 50, 'y_frac': 0.85},
    60: {'text': 'Sins of\nthe Father', 'x': 60, 'y_frac': 0.85},
    70: {'text': 'hard Kandarin diary', 'x': 70, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'crafting'
annotations = {
    40: {'text': 'Fremennik Trials/\nmedium Falador diary', 'x': 37, 'y_frac': 0.75},
    50: {'text': 'Legends\'\nQuest', 'x': 47, 'y_frac': 0.85},
    55: {'text': 'slayer helmet/\nhard Desert diary', 'x': 55, 'y_frac': 0.85},
    61: {'text': 'Lunar\nDiplomacy', 'x': 64, 'y_frac': 0.85},
    70: {'text': 'MM2', 'x': 70, 'y_frac': 0.90},
    75: {'text': 'slayer\nrings', 'x': 75, 'y_frac': 0.85},
    80: {'text': 'elite\nFremennik diary', 'x': 83, 'y_frac': 0.80},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'herblore'
annotations = {
    3: {'text': 'Druidic Ritual\nquest reward\n(250 xp)', 'x': 5, 'y_frac': 0.65},
    10: {'text': 'Druidic Ritual + Recruitment Drive\nquest rewards (1250 xp)', 'x': 12, 'y_frac': 0.85},
    45: {'text': 'Legends\' Quest', 'x': 45, 'y_frac': 0.90},
    57: {'text': 'Fairy Tale II', 'x': 54, 'y_frac': 0.90},
    58: {'text': 'herb sack', 'x': 62, 'y_frac': 0.90},
    70: {'text': 'SoTE', 'x': 70, 'y_frac': 0.90},
    90: {'text': 'overload (+)/\nelite Varrock diary', 'x': 87, 'y_frac': 0.85},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'mining'
annotations = {
    15: {'text': 'several easy diaries', 'x': 12, 'y_frac': 0.70},
    20: {'text': 'Tears of Guthix', 'x': 23, 'y_frac': 0.75},
    40: {'text': 'several medium diaries', 'x': 37, 'y_frac': 0.80},
    50: {'text': 'Heroes\' Quest', 'x': 49, 'y_frac': 0.90},
    60: {'text': 'Lunar Diplomacy', 'x': 60, 'y_frac': 0.90},
    68: {'text': 'DS2', 'x': 68, 'y_frac': 0.90},
    70: {'text': 'SoTE', 'x': 72, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'woodcutting'
annotations = {
    36: {'text': 'Lost City', 'x': 36, 'y_frac': 0.70},
    50: {'text': 'Legends\' Quest', 'x': 47, 'y_frac': 0.80},
    55: {'text': 'Lunar Diplomacy', 'x': 53, 'y_frac': 0.90},
    61: {'text': 'Dragon axe', 'x': 63, 'y_frac': 0.90},
    70: {'text': 'SoTE', 'x': 70, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'fishing'
annotations = {
    20: {'text': 'easy Varrock diary', 'x': 20, 'y_frac': 0.65},
    40: {'text': 'lobsters', 'x': 40, 'y_frac': 0.65},
    50: {'text': 'swordfish', 'x': 47, 'y_frac': 0.85},
    53: {'text': 'Heroes\'\nQuest', 'x': 53, 'y_frac': 0.85},
    60: {'text': 'Fremennik\nExiles', 'x': 59, 'y_frac': 0.85},
    65: {'text': 'medium\nKaramja diary', 'x': 66, 'y_frac': 0.85},
    70: {'text': 'hard Karamja diary', 'x': 75, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'hunter'
annotations = {
    9: {'text': 'Natural history\nquiz reward (1000 xp)', 'x': 9, 'y_frac': 0.85},
    29: {'text': 'medium\nMorytania diary', 'x': 29, 'y_frac': 0.80},
    40: {'text': 'spotted cape', 'x': 40, 'y_frac': 0.80},
    60: {'text': 'MM2', 'x': 59, 'y_frac': 0.85},
    66: {'text': 'hard\nVarrock diary', 'x': 66, 'y_frac': 0.85},
    70: {'text': 'SoTE', 'x': 72, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'farming'
annotations = {
    9: {'text': 'RFD (goblin generals)\nquest reward (1000 xp)', 'x': 8, 'y_frac': 0.85},
    17: {'text': 'Fairy Tale I quest\nreward (3500 xp)', 'x': 21, 'y_frac': 0.85},
    20: {'text': 'RFD + Fairy Tale I\nquest rewards (4500 xp)', 'x': 34, 'y_frac': 0.85},
    70: {'text': 'SoTE', 'x': 70, 'y_frac': 0.90},
    99: {'text': 'skill cape', 'x': 96, 'y_frac': 0.90}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)

# %%
skill = 'total'
annotations = {
    2106: {'text': 'likely missing\ndata', 'x': 2175, 'y_frac': 0.85},
    2266: {'text': '', 'x': 2175, 'y_frac': 0.85}
}

out_file='../../reports/figures/{}-levels-histogram.pdf'.format(skill)
player_skills_histogram(levels, skill, out_file, annotations)
