# %%
import math
import pickle
import matplotlib as mpl
import numpy as np
import umap
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
with open('../data/processed/centroids.pkl', 'rb') as f:
    percentiles = pickle.load(f)
with open('../data/processed/clusters.pkl', 'rb') as f:
    cluster_results = pickle.load(f)

# %%
np.random.seed(0)

# %%
for split in ['all', 'cb', 'noncb']:
    centroids = percentiles[split][50]
    cluster_sizes = cluster_results[split]['cluster_sizes']

    for n_neighbors in [5, 10, 15, 20]:
        for min_dist in [0.0, 0.1, 0.25, 0.5]:
            print("running split '{}', n_neighbors = {}, min_dist = {}"
                  .format(split, n_neighbors, min_dist))

            fit = umap.UMAP(
                n_neighbors=n_neighbors,
                min_dist=min_dist,
                n_components=3,
                metric='euclidean'
            )
            # %time u = fit.fit_transform(centroids)

            fig = plt.figure(figsize=(12, 12))

            ax = fig.add_subplot(111, projection='3d')
            title_split = {
                'all': 'all',
                'cb': 'combat',
                'noncb': 'non-combat'
            }[split]
            plt.title("OSRS players clustered by {} skills".format(title_split),
                      weight='bold', fontsize=16, y=1.0, pad=14)
            sizes = (1 + np.log(cluster_sizes)) ** 2
            colors = np.sum(centroids, axis=1)
            ax.scatter(u[:,0], u[:,1], u[:,2], c=colors, s=sizes, alpha=0.25)

            xlim = [np.min(u[:, 0]), np.max(u[:, 0])]
            ylim = [np.min(u[:, 1]), np.max(u[:, 1])]
            zlim = [np.min(u[:, 2]), np.max(u[:, 2])]
            ax.set_xticks(range(math.ceil(xlim[0]), math.floor(xlim[1]) + 1))
            ax.set_yticks(range(math.ceil(ylim[0]), math.floor(ylim[1]) + 1))
            ax.set_zticks(range(math.ceil(zlim[0]), math.floor(zlim[1]) + 1))
            ax.set_xlim(xlim)
            ax.set_ylim(ylim)
            ax.set_zlim(zlim)

            cax = plt.axes([0.18, 0.12, 0.675, 0.04])
            norm = mpl.colors.Normalize(vmin=1, vmax=2277)
            cbar = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.viridis),
                                cax=cax, orientation='horizontal')
            cbar.set_label('Total level', size=14)
            min_dist_text = '{:0.2}'.format(min_dist).ljust(4, '0')
            fig.savefig('../reports/scatterplots/player-clusters-{}-{}-{}.pdf'
                        .format(split, n_neighbors, min_dist_text),
                        bbox_inches='tight')
            plt.clf()
# Out:
# running split 'all', n_neighbors = 5, min_dist = 0.0
# OMP: Info #273: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# CPU times: user 17.8 s, sys: 4.8 s, total: 22.6 s
# Wall time: 16.8 s
# running split 'all', n_neighbors = 5, min_dist = 0.1
# CPU times: user 10.4 s, sys: 4.69 s, total: 15.1 s
# Wall time: 9.24 s
# running split 'all', n_neighbors = 5, min_dist = 0.25
# CPU times: user 10.5 s, sys: 4.96 s, total: 15.4 s
# Wall time: 9.12 s
# running split 'all', n_neighbors = 5, min_dist = 0.5
# CPU times: user 10.1 s, sys: 4.47 s, total: 14.5 s
# Wall time: 8.9 s
# running split 'all', n_neighbors = 10, min_dist = 0.0
# CPU times: user 12.7 s, sys: 3.42 s, total: 16.1 s
# Wall time: 11.8 s
# running split 'all', n_neighbors = 10, min_dist = 0.1
# CPU times: user 12.7 s, sys: 3.73 s, total: 16.5 s
# Wall time: 11.8 s
# running split 'all', n_neighbors = 10, min_dist = 0.25
# CPU times: user 12.5 s, sys: 2.49 s, total: 14.9 s
# Wall time: 11.9 s
# running split 'all', n_neighbors = 10, min_dist = 0.5
# CPU times: user 12.6 s, sys: 2.98 s, total: 15.5 s
# Wall time: 11.8 s
# running split 'all', n_neighbors = 15, min_dist = 0.0
# CPU times: user 14.6 s, sys: 3.41 s, total: 18 s
# Wall time: 13.7 s
# running split 'all', n_neighbors = 15, min_dist = 0.1
# CPU times: user 14.6 s, sys: 3.06 s, total: 17.6 s
# Wall time: 13.7 s
# running split 'all', n_neighbors = 15, min_dist = 0.25
# CPU times: user 14.6 s, sys: 3.67 s, total: 18.2 s
# Wall time: 13.6 s
# running split 'all', n_neighbors = 15, min_dist = 0.5
# CPU times: user 14.6 s, sys: 3.91 s, total: 18.5 s
# Wall time: 13.6 s
# running split 'all', n_neighbors = 20, min_dist = 0.0
# CPU times: user 16.1 s, sys: 3.57 s, total: 19.7 s
# Wall time: 15.2 s
# running split 'all', n_neighbors = 20, min_dist = 0.1
# CPU times: user 16.1 s, sys: 2.17 s, total: 18.2 s
# Wall time: 15.4 s
# running split 'all', n_neighbors = 20, min_dist = 0.25
# CPU times: user 16 s, sys: 3.21 s, total: 19.2 s
# Wall time: 15.1 s
# running split 'all', n_neighbors = 20, min_dist = 0.5
# CPU times: user 16.2 s, sys: 3.45 s, total: 19.6 s
# Wall time: 15.3 s
# running split 'cb', n_neighbors = 5, min_dist = 0.0
# CPU times: user 9.42 s, sys: 2.57 s, total: 12 s
# Wall time: 8.92 s
# running split 'cb', n_neighbors = 5, min_dist = 0.1
# CPU times: user 7.5 s, sys: 2.46 s, total: 9.95 s
# Wall time: 6.98 s
# running split 'cb', n_neighbors = 5, min_dist = 0.25
# CPU times: user 7.43 s, sys: 2.41 s, total: 9.83 s
# Wall time: 6.91 s
# running split 'cb', n_neighbors = 5, min_dist = 0.5
# CPU times: user 7.39 s, sys: 2.76 s, total: 10.2 s
# Wall time: 6.84 s
# running split 'cb', n_neighbors = 10, min_dist = 0.0
# CPU times: user 7.99 s, sys: 2.05 s, total: 10 s
# Wall time: 7.58 s
# /var/folders/64/cb4nqjh958z56qw77tfx3mnw0000gn/T/ipykernel_92683/4234308120.py:18: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(12, 12))
# running split 'cb', n_neighbors = 10, min_dist = 0.1
# CPU times: user 8.13 s, sys: 1.77 s, total: 9.9 s
# Wall time: 7.71 s
# running split 'cb', n_neighbors = 10, min_dist = 0.25
# CPU times: user 8.14 s, sys: 2.31 s, total: 10.4 s
# Wall time: 7.67 s
# running split 'cb', n_neighbors = 10, min_dist = 0.5
# CPU times: user 8.15 s, sys: 2.18 s, total: 10.3 s
# Wall time: 7.71 s
# running split 'cb', n_neighbors = 15, min_dist = 0.0
# CPU times: user 8.51 s, sys: 1.84 s, total: 10.4 s
# Wall time: 8.16 s
# running split 'cb', n_neighbors = 15, min_dist = 0.1
# CPU times: user 8.57 s, sys: 2.12 s, total: 10.7 s
# Wall time: 8.13 s
# running split 'cb', n_neighbors = 15, min_dist = 0.25
# CPU times: user 8.52 s, sys: 1.76 s, total: 10.3 s
# Wall time: 8.26 s
# running split 'cb', n_neighbors = 15, min_dist = 0.5
# CPU times: user 8.64 s, sys: 2.16 s, total: 10.8 s
# Wall time: 8.23 s
# running split 'cb', n_neighbors = 20, min_dist = 0.0
# CPU times: user 8.85 s, sys: 1.7 s, total: 10.6 s
# Wall time: 8.54 s
# running split 'cb', n_neighbors = 20, min_dist = 0.1
# CPU times: user 8.79 s, sys: 1.43 s, total: 10.2 s
# Wall time: 8.49 s
# running split 'cb', n_neighbors = 20, min_dist = 0.25
# CPU times: user 8.92 s, sys: 1.74 s, total: 10.7 s
# Wall time: 8.58 s
# running split 'cb', n_neighbors = 20, min_dist = 0.5
# CPU times: user 8.93 s, sys: 1.79 s, total: 10.7 s
# Wall time: 8.58 s
# running split 'noncb', n_neighbors = 5, min_dist = 0.0
# CPU times: user 10.3 s, sys: 2.23 s, total: 12.5 s
# Wall time: 9.83 s
# running split 'noncb', n_neighbors = 5, min_dist = 0.1
# CPU times: user 10.2 s, sys: 2.02 s, total: 12.2 s
# Wall time: 9.81 s
# running split 'noncb', n_neighbors = 5, min_dist = 0.25
# CPU times: user 10.3 s, sys: 1.89 s, total: 12.2 s
# Wall time: 9.99 s
# running split 'noncb', n_neighbors = 5, min_dist = 0.5
# CPU times: user 10.4 s, sys: 1.78 s, total: 12.2 s
# Wall time: 10.2 s
# running split 'noncb', n_neighbors = 10, min_dist = 0.0
# CPU times: user 11.7 s, sys: 1.86 s, total: 13.6 s
# Wall time: 11.5 s
# running split 'noncb', n_neighbors = 10, min_dist = 0.1
# CPU times: user 11.4 s, sys: 1.58 s, total: 13 s
# Wall time: 11.1 s
# running split 'noncb', n_neighbors = 10, min_dist = 0.25
# CPU times: user 11.5 s, sys: 1.52 s, total: 13 s
# Wall time: 11.2 s
# running split 'noncb', n_neighbors = 10, min_dist = 0.5
# CPU times: user 11.5 s, sys: 1.84 s, total: 13.3 s
# Wall time: 11.2 s
# running split 'noncb', n_neighbors = 15, min_dist = 0.0
# CPU times: user 12.1 s, sys: 1.57 s, total: 13.7 s
# Wall time: 11.9 s
# running split 'noncb', n_neighbors = 15, min_dist = 0.1
# CPU times: user 12.2 s, sys: 1.69 s, total: 13.9 s
# Wall time: 11.9 s
# running split 'noncb', n_neighbors = 15, min_dist = 0.25
# CPU times: user 12.2 s, sys: 1.71 s, total: 14 s
# Wall time: 11.9 s
# running split 'noncb', n_neighbors = 15, min_dist = 0.5
# CPU times: user 12.1 s, sys: 1.61 s, total: 13.7 s
# Wall time: 11.8 s
# running split 'noncb', n_neighbors = 20, min_dist = 0.0
# CPU times: user 12.6 s, sys: 1.18 s, total: 13.8 s
# Wall time: 12.4 s
# running split 'noncb', n_neighbors = 20, min_dist = 0.1
